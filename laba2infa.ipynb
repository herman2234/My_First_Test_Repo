# %% [markdown]
# <a href="https://colab.research.google.com/github/herman2234/My_First_Test_Repo/blob/main/laba2infa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчёт бригады из группы ЭН2-52
# - Напалков Герман
# - Спиридонов Влад
# - Евтющенко Кирилл
#
#
#
# ![Логотип](https://upload.wikimedia.org/wikipedia/en/thumb/b/b2/Fallout_Brotherhood_of_Steel_Logo.svg/250px-Fallout_Brotherhood_of_Steel_Logo.svg.png)
#
# | Задание | Выполнено |
# |---------|-----------|
# | GitHub  | ✅       |
# | Colab   | ✅       |
#
# Ссылка на [университет](https://nstu.ru)
